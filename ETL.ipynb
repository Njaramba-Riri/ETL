# %%
import pyforest

# %%
df=pd.read_csv('crypto-markets.csv')

# %%
df.head()
# Out:
#           slug asset         name        date  ranknow      open      high  \
# 0  target-coin   TGT  Target Coin  29-09-2017      607  0.028961  0.054766
# 1  target-coin   TGT  Target Coin  30-09-2017      607  0.041783  0.046196
# 2  target-coin   TGT  Target Coin  01-10-2017      607  0.031761  0.035957
# 3  target-coin   TGT  Target Coin  02-10-2017      607  0.028375  0.054595
# 4  target-coin   TGT  Target Coin  03-10-2017      607  0.022527  0.032225
#
#         low     close  volume  market  close_ratio  spread
# 0  0.028961  0.041777   69996     0.0       0.4966    0.03
# 1  0.031435  0.031744    5725     0.0       0.0209    0.01
# 2  0.021040  0.028385    5012     0.0       0.4924    0.01
# 3  0.020417  0.022525    8010     0.0       0.0617    0.03
# 4  0.020211  0.020359    1787     0.0       0.0123    0.01

# %%
df.columns
# Out:
# Index(['slug', 'asset', 'name', 'date', 'ranknow', 'open', 'high', 'low',
#        'close', 'volume', 'market', 'close_ratio', 'spread'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1587 entries, 0 to 1586
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   slug         1587 non-null   object
#  1   asset        1587 non-null   object
#  2   name         1587 non-null   object
#  3   date         1587 non-null   object
#  4   ranknow      1587 non-null   int64
#  5   open         1587 non-null   float64
#  6   high         1587 non-null   float64
#  7   low          1587 non-null   float64
#  8   close        1587 non-null   float64
#  9   volume       1587 non-null   int64
#  10  market       1587 non-null   float64
#  11  close_ratio  1587 non-null   float64
#  12  spread       1587 non-null   float64
# dtypes: float64(7), int64(2), object(4)
# memory usage: 161.3+ KB

# %%
df.asset.unique()
# Out:
# array(['TGT', 'symbol', 'HGT', 'HBZ', 'GET', 'ETHOS', 'DASH', 'CBT',
#        'BTC', 'AIR', 'XRP', 'LTC'], dtype=object)

# %% [markdown]
# - Transformation

# %%
assetsCode=['BTC','ETH','XRP','LTC']

#convert open, close, high, and low price into GBP from dollars

df['open']=df[['open', 'asset']].apply(lambda x: (float(x[0]) * 0.80) if x[1] in assetsCode else np.nan, axis=1)

df['close'] = df[['close', 'asset']].apply(lambda x: (float(x[0]) * 0.80) if x[1] in assetsCode else np.nan, axis=1)

df['high'] = df[['high', 'asset']].apply(lambda x: (float(x[0]) * 0.80) if x[1] in assetsCode else np.nan, axis=1)

df['low'] = df[['low', 'asset']].apply(lambda x: (float(x[0]) * 0.80) if x[1] in assetsCode else np.nan, axis=1)


#drop rows with null values by asset column
df.dropna(inplace=True)

#reset the dataframe index
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#       slug asset     name        date  ranknow     open     high      low  \
# 0  bitcoin   BTC  Bitcoin  28-04-2013        1  108.240  108.784  105.680
# 1  bitcoin   BTC  Bitcoin  29-04-2013        1  107.552  117.992  107.200
# 2  bitcoin   BTC  Bitcoin  30-04-2013        1  115.200  117.544  107.240
# 3  bitcoin   BTC  Bitcoin  01-05-2013        1  111.200  111.912   86.176
# 4  bitcoin   BTC  Bitcoin  02-05-2013        1   93.104  100.480   73.824
#
#      close  volume        market  close_ratio  spread
# 0  107.368       0  1.500520e+09       0.5438    3.88
# 1  115.632       0  1.491160e+09       0.7813   13.49
# 2  111.200       0  1.597780e+09       0.3843   12.88
# 3   93.592       0  1.542820e+09       0.2882   32.17
# 4   84.168       0  1.292190e+09       0.3881   33.32

# %%
df.head()
# Out:
#       slug asset     name        date  ranknow     open     high      low  \
# 0  bitcoin   BTC  Bitcoin  28-04-2013        1  108.240  108.784  105.680
# 1  bitcoin   BTC  Bitcoin  29-04-2013        1  107.552  117.992  107.200
# 2  bitcoin   BTC  Bitcoin  30-04-2013        1  115.200  117.544  107.240
# 3  bitcoin   BTC  Bitcoin  01-05-2013        1  111.200  111.912   86.176
# 4  bitcoin   BTC  Bitcoin  02-05-2013        1   93.104  100.480   73.824
#
#      close  volume        market  close_ratio  spread
# 0  107.368       0  1.500520e+09       0.5438    3.88
# 1  115.632       0  1.491160e+09       0.7813   13.49
# 2  111.200       0  1.597780e+09       0.3843   12.88
# 3   93.592       0  1.542820e+09       0.2882   32.17
# 4   84.168       0  1.292190e+09       0.3881   33.32

# %%
df.drop(labels=['slug','ranknow','volume','market','close_ratio','spread'],
       inplace=True,axis=1)

# %%
df.head()
# Out:
#   asset     name        date     open     high      low    close
# 0   BTC  Bitcoin  28-04-2013  108.240  108.784  105.680  107.368
# 1   BTC  Bitcoin  29-04-2013  107.552  117.992  107.200  115.632
# 2   BTC  Bitcoin  30-04-2013  115.200  117.544  107.240  111.200
# 3   BTC  Bitcoin  01-05-2013  111.200  111.912   86.176   93.592
# 4   BTC  Bitcoin  02-05-2013   93.104  100.480   73.824   84.168

# %%
import sqlite3

# %%
#connect function opens a connection to the sqlite database file
conn=sqlite3.connect('session.db')


#dropa table named crypto if it exists already

try:
    conn.execute('DROP TABLE IF EXISTS `Crypto` ')
except Exception as e:
    raise(e)
finally:
    print('Table Dropped')
    
    
    
#Create new table nameed crypto
try:
    conn.execute('''
        CREATE TABLE Crypto(
        ID INT PRIMARY KEY,
        ASSET TEXT NOT NULL,
        NAME TEXT NOT NULL,
        Date datetime,
        Open Float DEFAULT 0,
        High Float DEFAULT 0,
        Low Float DEFAULT 0,
        Close Float DEFAULT 0
        );
    ''')
    print('Table created successfully ');
    
except Exception as e:
    print(str(e))
    print('Table Creation Failed!!')
finally:
    conn.close()#closes db connection
# Out:
# Table Dropped
# Table created successfully

# %%
#Data insertion
#convert pandas DF to list of list
cry_list=df.values.tolist()

#create new connection to insert crypto data into SQL DB.
conn=sqlite3.connect('session.db')


#make a cursor to help in querying the DB
cur=conn.cursor()

try:
    cur.executemany("INSERT INTO Crypto(ASSET,NAME,Date,Open,High,Low,Close) VALUES(?,?,?,?,?,?,?)",cry_list)
    conn.commit()
    print("Data Inserted Successfully.")
    
except Exception as e:
    print(str(e))
    print('Data Insertion Failed')
finally:
    conn.close()
# Out:
# Data Inserted Successfully.
